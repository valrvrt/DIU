# %%
import json
from pathlib import Path
from typing import List, Optional

file_path = "/Users/val/Desktop/Pythoneries/DUNE Imperium Uprising/data/conflicts.JSON"

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import json
#       2 from pathlib import Path
#       3 from typing import List, Optional
#       4
# ----> 5 file_path = _get_data_path("/Users/val/Desktop/Pythoneries/DUNE Imperium Uprising/data/conflicts.JSON")
#       6
#       7 with open(file_path, 'r', encoding='utf-8') as f:
#       8     data = json.load(f)
#
# Cell In[3], line 8, in _get_data_path(filename)
#       6 def _get_data_path(filename: str) -> Path:
#       7     """Get path to data file."""
# ----> 8     return Path(__file__).parent.parent.parent / "data" / filename
#
# NameError: name '__file__' is not defined
